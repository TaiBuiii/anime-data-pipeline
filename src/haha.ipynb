# %%
from utils.logger import get_logger
from db_init import run_ddl
from ingestion.bronze_orchestrator import run_ingestion
from transformation.silver.silver_orchestrator import run_transformation

logger = get_logger(__name__)

if __name__ == "__main__":
    logger.info("================Run main.py===============")
    # run_ddl()
    # run_ingestion()
    run_transformation()

# %%
for key,value in silver_schema.items():
    print(key)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 for key,value in silver_schema.items():
#       2     print(key)
#
# NameError: name 'silver_schema' is not defined

# %%
df = silver_schema["anime"]
df[df["anime_mal_id"] == 59599]
