# %%
from utils.logger import get_logger
from db_init import run_ddl
from ingestion.bronze_orchestrator import run_ingestion
from transformation.silver.silver_orchestrator import run_transformation

logger = get_logger(__name__)

if __name__ == "__main__":
    logger.info("================Run main.py===============")
    # run_ddl()
    # run_ingestion()
    silver_schema = run_transformation()

# %%
for key,value in silver_schema.items():
    print(key)
# Out:
# anime
# broadcast
# rating
# anime_theme
# theme
# anime_demographic
# demographic
# anime_genre
# genre
# anime_organization
# organization

# %%
df = silver_schema["broadcast"]
df
# Out:
#        broadcast_id broadcast_day broadcast_time broadcast_timezone
# 0                 1          <NA>            NaT               <NA>
# 13                2       fridays       01:28:00         asia/tokyo
# 70                3     saturdays       01:53:00         asia/tokyo
# 165               4       sundays       03:20:00         asia/tokyo
# 297               5       fridays       22:00:00         asia/tokyo
# ...             ...           ...            ...                ...
# 28314           683    wednesdays       23:05:00         asia/tokyo
# 28378           684       sundays       09:55:00         asia/tokyo
# 28429           685       sundays       14:30:00         asia/tokyo
# 28460           686     thursdays       18:40:00         asia/tokyo
# 29137           687     thursdays       01:32:00         asia/tokyo
#
# [687 rows x 4 columns]
